# %%
from novel_agent import write_story_loop

# %%
write_story_loop()
# Out:
# 📚 啟動小說連續創作模式！
# 📍 目前最新章節：第 0 章
# 🚀 將從第 1 章開始寫作
#
# 📘 開始撰寫第 1 章...
#
#
# 🎯 為你規劃章節子目標中...
#
# 💬 本章子目標內容如下：
# ...
# 假設主要目標是"主角成功找回失踪的父親並揭露家族祕密"，以下為子目標的建議：
# ...
#
#
# ✅ 第 1 章初稿完成，以下是內容預覽：
#
# ...
# 阿羅恩村的早晨充滿了靜謐與祥和，唯獨伊澤·艾爾文從他的茅草屋裡走出來時，總帶著一股遣人心酸的冷酷和專註。
#
# 他今日的目標，是前往村邊的迷霧森林，也是他父親最後被目擊的地方。他把沈甸甸的行囊甩在肩上，握緊了手中的魔法杖，會心一笑，今日，他將再次挑戰那片充滿未知恐懼的森林。
#
# 他獨自在晨霧中行走，途中遇見的村民都對他平易近人的笑容投以疑惑的目光，伊澤卻無視他們，背上行囊的重量，使他忘卻了村裡的是非與喧囂。
#
# 森林的邊緣，一片蔚藍色的風鈴花在陽光下閃爍著微光，這是他父親種植的，每年此刻，都會為阿羅恩村帶來一道美麗的風景線。看著這些風鈴花，伊澤不禁想起父親那溫暖而堅定的目光，那是他對魔法的熱愛，也是他對家庭的期許。
#
# 眼前的迷霧森林，總是讓人感到恐懼與不安。伊澤深吸一口氣，然後，他握緊魔法杖，開始了他的探索。
#
# 他的步伐穩定而有力，心中充滿了期待與憧憬。他用魔法杖將前方的藤蔓劃開，同時保持警覺，做好隨時應對的準備。
#
# 森林的深處，伊澤發現了一片荒廢的小屋。他小心翼翼地靠近，發現門口的風鈴花盆裡，枯萎的風鈴花正是父親種植的。
#
# 他緩緩推開小屋的門，裡面灰塵滿佈，但卻保有一種他熟悉的氣息。他在積滿灰塵的書桌上找到了一本舊日記，當他小心翼翼地翻開日記，裡面滿是父親研究禁咒的筆記。
#
# 他緊握著日記，心中充滿了混亂和驚愕。他望著灰塵飄揚的小屋，再次感受到父親失蹤這個事實的殘酷。他強壓下心中的悲痛，慎重地收起日記，然後，他堅定地走出小屋。
#
# 他知道，他必須繼續前進，才能找到父親失蹤的真相。他將把父親的日記帶回星環之塔，解開禁咒的秘密。他要用父親的筆記，繼續寫下他們家族的故事。
# ...
#
# 🚧 執行擴寫並覆蓋原章節...
#
#
# 🧪 GPT 回傳結果預覽（前 300 字）：
#
# 【擴寫建議】
# ...
